# %% [markdown]
# #Operadores Relacionais

# %% [markdown]
# #>maior
# #>= maior igual
# #* <= menor igual
# #* != diferente
# #* ==igual

# %%
10 > 20 # 10 é maior que 20
# Out:
# False

# %%
10 < 20 # 10 é menor que 20
# Out:
# True

# %%
5=1 != 6 # 5=1 é diferente de 6
# Out:
#   File "/tmp/ipython-input-233196780.py", line 1
#     5=1 != 6 # 5=1 é diferente de 6
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
3+1 >= 4 # 3+1 é maior ou igual a 4

# %%
nome_aluno = "Pratricia"
nome_professor = "Lucas"

# %%
nome_aluno == nome_professor

# %%
10 != 10
# Out:
# False

# %% [markdown]
# #operadores logicos

# %% [markdown]
# * AND (e)
# * OR (ou)
# * NOT (negação)

# %%
(10 > 20) and (20 > 30)
# Out:
# False

# %% [markdown]
# #AND
#
# true + true = true
#
# true + false + False
#
# false + true = false
#
# false + false = false

# %%
(10>20) and (20>30) # False + False = False
# Out:
# False

# %%
(10<20) and (20 <30)
# Out:
# True

# %% [markdown]
# # OR
#
# true + true = true
#
# true + false = true
#
# false + true = true
#
# false + false = false

# %%
(1 < 2) or (3 > 6)
# Out:
# True

# %%
'João' == 'João' or 'Python' != 'python'
# Out:
# True

# %% [markdown]
# #Not

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
n1= 5
n2= 7
Média n1 + n2
print( n1, n2, Média)
# Out:
#   File "/tmp/ipython-input-1244243000.py", line 3
#     Média n1 + n2
#           ^
# SyntaxError: invalid syntax
